# %%
# confusion matrix
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_test, y_pred, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Greys):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure()
    cm = confusion_matrix(y_test, y_pred)
    # np.set_printoptions(precision=2)


    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, "{0:.4f}".format(cm[i, j]),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    
    
    
    #Roc


def plot_roc_curve(Y_test, Y_pred, nb_classes, class_index, title='Receiver operating characteristic'):
    from sklearn import metrics
    import matplotlib.pyplot as plt
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(nb_classes):
        fpr[i], tpr[i], _ = metrics.roc_curve(Y_test[:, i], Y_pred[:, i])
        roc_auc[i] = metrics.auc(fpr[i], tpr[i])
    
    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = metrics.roc_curve(Y_test.ravel(), Y_pred.ravel())
    roc_auc["micro"] = metrics.auc(fpr["micro"], tpr["micro"])
    
    #plt.figure()
    lw = 2
    plt.plot(fpr[class_index], tpr[class_index], color='darkorange',
             lw=lw, label='ROC curve (area = %0.4f)' % roc_auc[class_index])
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(title)
    plt.legend(loc="lower right")
    plt.show()
    
    #epoch history
    

def plot_hist(hist, metrics, num=None):
    import matplotlib.pyplot as plt
    if num is not None:
        fig = plt.figure(num)
    else:
        fig = plt.figure()
    ax1 = fig.add_subplot(111)
    for metric in metrics:
        ax1.plot(hist.history[metric], label=metric)
    # plt.plot(history.history['val_acc'])
    # ax.ylabel(metric)
    plt.title('model history')
    plt.xlabel('epoch')
    #plt.legend(['train', 'test'], loc='upper left')
    plt.legend(loc='upper right');
    plt.show()

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Input, merge, Lambda
from keras.models import Model
from keras.optimizers import SGD
import numpy as np

from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from keras.regularizers import l2 as activity_l2

from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

#from sklearn.metrics import confusion_matrix as cm
#from sklearn.metrics import roc_curve as roc
#from mlxtend.plotting import plot_confusion_matrix

#tagy
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
tf.Session(config=config)

print('Loading normalized data from HDF5...')
import h5py
h5f = h5py.File('datasets_100.h5', 'r')
X_train = h5f['X_nn_train'].value
Y_train = h5f['Y_nn_train'].value.astype(np.float32)
X_test = h5f['X_nn_test'].value
Y_test = h5f['Y_nn_test'].value.astype(np.float32)

X_train2 = h5f['X_rf_train'].value
Y_train2 = h5f['Y_rf_train'].value.astype(np.float32)
X_test2 = h5f['X_rf_test'].value
Y_test2 = h5f['Y_rf_test'].value.astype(np.float32)
h5f.close()


from sklearn.ensemble import ExtraTreesClassifier

print('Training ExtraTreesClassifier for "attack or not" labels...')
print('model2')
model2 = ExtraTreesClassifier(n_estimators=31, criterion='entropy')
model2 = model2.fit(X_train2, Y_train2)
Y_pred2 = model2.predict_proba(X_test2)[:,1]

print('Testing accuracy...')
score2 = accuracy_score(Y_test2, np.around(Y_pred2))
print(score2)
print(classification_report(Y_test2, np.around(Y_pred2)))

def perf_measure(y_actual, y_hat):
    TP = 0
    FP = 0
    TN = 0
    FN = 0

    for i in range(len(y_hat)): 
        if y_actual[i]==y_hat[i]==1:
           TP += 1
    for i in range(len(y_hat)): 
        if y_hat[i]==1 and y_actual[i]!=y_hat[i]:
           FP += 1
    for i in range(len(y_hat)): 
        if y_actual[i]==y_hat[i]==0:
           TN += 1
    for i in range(len(y_hat)): 
        if y_hat[i]==0 and y_actual[i]!=y_hat[i]:
           FN += 1

    return(TP, FP, TN, FN)

TP, FP, TN, FN = perf_measure(np.around(Y_pred2), Y_test2)

fp_rate = FP/(TN+FP)
tn_rate = TN/(TN+FP)

accuracy = (TN+TP)/(TN+FP+TP+TN)
precision = TP/(TN+FP)
hitrate = TP/(TN+FN)

print('TP:', TP, 'FP:', FP, 'TN:', TN, 'FN:', FN)
print('Accuracy:', accuracy)
print('False Positive rate:', fp_rate, 'True Negative Rate', tn_rate)

def to_cat(y):
    y_tmp = np.ndarray(shape=(y.shape[0], 2), dtype=np.float32)
    for i in range(y.shape[0]):
        y_tmp[i, :] = np.array([1-y[i], y[i]])   # np.array([0,1]) if y[i] else np.array([1,0])
    return y_tmp


plot_confusion_matrix(Y_test2, np.round(Y_pred2), classes=list(range(2)),
                           normalize=True,
                         title='"Intrusion or normal" confusion matrix')

plot_roc_curve(to_cat(Y_test2), to_cat(Y_pred2), 2, 0, title='Receiver operating characteristic (attack_or_not = 0)')
plot_roc_curve(to_cat(Y_test2), to_cat(Y_pred2), 2, 1, title='Receiver operating characteristic (attack_or_not = 1)')






if 'session' in locals() and session is not None:
    print('Close interactive session')
    session.close()
    
#  Starting Network shit


print('Combining predicted "attack or not" labels to neural network testing data...')
X_test = np.concatenate((Y_pred2[:,np.newaxis], X_test), axis=1)

print('Creating neural network...')
num_of_features = X_train.shape[1]
nb_classes = Y_train.shape[1]


def residual_layer(size, x):
    
    y = Dense(size, activation='sigmoid', W_regularizer=l2(0.01), activity_regularizer=activity_l2(0.01))(x)
    # x = Dropout(0.5)(x)
    # print(x.get_shape().as_list()[1])
    y = Dense(x.get_shape().as_list()[1], activation='sigmoid',  W_regularizer=l2(0.01), activity_regularizer=activity_l2(0.01))(y)
    res = merge([y, x], mode='sum')
    return res


def baseline_model():
    def branch2(x):
        
        x = Dense(int(np.floor(num_of_features*50)), activation='relu')(x)
        x = Dropout(0.75)(x)
        
        x = Dense(int(np.floor(num_of_features*20)), activation='relu')(x)
        x = Dropout(0.5)(x)
        
        x = Dense(int(np.floor(num_of_features)), activation='relu')(x)
        x = Dropout(0.1)(x)
        return x
    
    main_input = Input(shape=(num_of_features,), name='main_input')

    x = main_input
    x = branch2(x)
    main_output = Dense(nb_classes, activation='softmax')(x)
    model = Model(input=main_input, output=main_output)    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', 'categorical_crossentropy'])
    model.summary()
    return model
print('model...')
model = baseline_model()

print('Training neural network...')
history = model.fit(X_train, Y_train,
                    epochs=100,
                    batch_size=128
                    )

print('Plotting training history data...')
print(history.history.keys())

#from  epoch_history_plot import  plot_hist

plot_hist(history, ['loss', 'acc'])

# summarize history for accuracy
import matplotlib.pyplot as plt
plt.figure()
plt.plot(history.history['acc'])
#plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
#plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.figure()
# summarize history for loss
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
#plt.legend(['train', 'test'], loc='upper left')
plt.show()

print('Testing neural network...')
Y_predicted = model.predict(X_test)

max_probs = np.argmax(Y_predicted, axis=1)
Y_pred = np.zeros(Y_predicted.shape)
for row, col in enumerate(max_probs):
    Y_pred[row,col] = 1

score = accuracy_score(Y_test, Y_pred)
print(score)
print(classification_report(Y_test.argmax(axis=-1), Y_pred.argmax(axis=-1)))


plot_confusion_matrix(Y_test.argmax(axis=-1), Y_pred.argmax(axis=-1), classes=list(range(10)),
                          normalize=True,
                          title='Confusion matrix')

print('Saving neural network model...')
json_string = model.to_json()
with open('neural_model1.json', 'w') as f:
    f.write(json_string)
model.save_weights('neural_model_weights1.h5')

model.save('neural_model1.h5')

plot_roc_curve(Y_test, Y_predicted, nb_classes, 6, title='Receiver operating characteristic (class 6)')
plot_roc_curve(Y_test, Y_predicted, nb_classes, 4, title='Receiver operating characteristic (class 4)')
plot_roc_curve(Y_test, Y_predicted, nb_classes, 2, title='Receiver operating characteristic (class 2)')
plot_roc_curve(Y_test, Y_predicted, nb_classes, 0, title='Receiver operating characteristic (class 0)')

print('model3')
model3 = ExtraTreesClassifier(n_estimators=31, criterion='entropy')
print('Fitting...')
model3 = model3.fit(X_train, Y_train.argmax(axis=-1))
print('Predicting...')
Y_predicted3 = model3.predict(X_test)

print('Testing accuracy...')
score3 = accuracy_score(Y_test.argmax(axis=-1), Y_predicted3)
print(score3)
print(classification_report(Y_test.argmax(axis=-1), Y_predicted3))

plot_confusion_matrix(Y_test.argmax(axis=-1), Y_predicted3, classes=list(range(10)),
                          normalize=True,
                          title='Extratrees Confusion matrix')


print('Saving X and Y to HDF5')
h5f = h5py.File('results.h5', 'w')
h5f.create_dataset('Y_predicted', data=Y_pred)
h5f.create_dataset('Y_expected', data=Y_test)
h5f.close()
# Out:
# Using TensorFlow backend.
# Loading normalized data from HDF5...
# /usr/local/lib/python3.5/dist-packages/h5py/_hl/dataset.py:313: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   "Use dataset[()] instead.", H5pyDeprecationWarning)
# Training ExtraTreesClassifier for "attack or not" labels...
# model2
# Testing accuracy...
# 0.9839759875918133
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.98      0.99   2187456
#          1.0       0.88      1.00      0.94    290263
#
#     accuracy                           0.98   2477719
#    macro avg       0.94      0.99      0.96   2477719
# weighted avg       0.99      0.98      0.98   2477719
#
# TP: 289967 FP: 296 TN: 2148049 FN: 39407
# Accuracy: 0.5315796118098859
# False Positive rate: 0.00013778047753037803 True Negative Rate 0.9998622195224697
# Normalized confusion matrix
# [[0.98198501 0.01801499]
#  [0.00101976 0.99898024]]
# Combining predicted "attack or not" labels to neural network testing data...
# Creating neural network...
# model...
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# main_input (InputLayer)      (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5000)              505000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5000)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2000)              10002000
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2000)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               200100
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 10,708,110
# Trainable params: 10,708,110
# Non-trainable params: 0
# _________________________________________________________________
# Training neural network...
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:150: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("ma..., outputs=Tensor("de...)`
# Epoch 1/100
# 36020/36020 [==============================] - 22s 616us/step - loss: 1.6482 - acc: 0.3624 - categorical_crossentropy: 1.6482
# Epoch 2/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.6180 - acc: 0.3724 - categorical_crossentropy: 1.6180
# Epoch 3/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.6149 - acc: 0.3716 - categorical_crossentropy: 1.6149
# Epoch 4/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.6119 - acc: 0.3750 - categorical_crossentropy: 1.6119
# Epoch 5/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.6095 - acc: 0.3764 - categorical_crossentropy: 1.6095
# Epoch 6/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.6107 - acc: 0.3768 - categorical_crossentropy: 1.6107
# Epoch 7/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.6077 - acc: 0.3754 - categorical_crossentropy: 1.6077
# Epoch 8/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.6084 - acc: 0.3756 - categorical_crossentropy: 1.6084
# Epoch 9/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.6057 - acc: 0.3757 - categorical_crossentropy: 1.6057
# Epoch 10/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.6049 - acc: 0.3773 - categorical_crossentropy: 1.6049
# Epoch 11/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.6054 - acc: 0.3760 - categorical_crossentropy: 1.6054
# Epoch 12/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.6049 - acc: 0.3757 - categorical_crossentropy: 1.6049
# Epoch 13/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.6037 - acc: 0.3778 - categorical_crossentropy: 1.6037
# Epoch 14/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.6028 - acc: 0.3785 - categorical_crossentropy: 1.6028
# Epoch 15/100
# 36020/36020 [==============================] - 1s 37us/step - loss: 1.6039 - acc: 0.3782 - categorical_crossentropy: 1.6039
# Epoch 16/100
# 36020/36020 [==============================] - 1s 37us/step - loss: 1.6027 - acc: 0.3780 - categorical_crossentropy: 1.6027
# Epoch 17/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.6006 - acc: 0.3765 - categorical_crossentropy: 1.6006
# Epoch 18/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.6015 - acc: 0.3766 - categorical_crossentropy: 1.6015
# Epoch 19/100
# 36020/36020 [==============================] - 1s 37us/step - loss: 1.6009 - acc: 0.3778 - categorical_crossentropy: 1.6009
# Epoch 20/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.6002 - acc: 0.3756 - categorical_crossentropy: 1.6002
# Epoch 21/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.6004 - acc: 0.3759 - categorical_crossentropy: 1.6004
# Epoch 22/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5997 - acc: 0.3773 - categorical_crossentropy: 1.5997
# Epoch 23/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5997 - acc: 0.3765 - categorical_crossentropy: 1.5997
# Epoch 24/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.6003 - acc: 0.3795 - categorical_crossentropy: 1.6003
# Epoch 25/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.6001 - acc: 0.3795 - categorical_crossentropy: 1.6001
# Epoch 26/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5988 - acc: 0.3783 - categorical_crossentropy: 1.5988
# Epoch 27/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5986 - acc: 0.3784 - categorical_crossentropy: 1.5986
# Epoch 28/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5980 - acc: 0.3796 - categorical_crossentropy: 1.5980
# Epoch 29/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5983 - acc: 0.3786 - categorical_crossentropy: 1.5983
# Epoch 30/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5977 - acc: 0.3783 - categorical_crossentropy: 1.5977
# Epoch 31/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5973 - acc: 0.3793 - categorical_crossentropy: 1.5973
# Epoch 32/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5966 - acc: 0.3785 - categorical_crossentropy: 1.5966
# Epoch 33/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5977 - acc: 0.3778 - categorical_crossentropy: 1.5977
# Epoch 34/100
# 36020/36020 [==============================] - 1s 37us/step - loss: 1.5968 - acc: 0.3790 - categorical_crossentropy: 1.5968
# Epoch 35/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5963 - acc: 0.3791 - categorical_crossentropy: 1.5963
# Epoch 36/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5974 - acc: 0.3773 - categorical_crossentropy: 1.5974
# Epoch 37/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5975 - acc: 0.3787 - categorical_crossentropy: 1.5975
# Epoch 38/100
# 36020/36020 [==============================] - 1s 37us/step - loss: 1.5966 - acc: 0.3784 - categorical_crossentropy: 1.5966
# Epoch 39/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5966 - acc: 0.3800 - categorical_crossentropy: 1.5966
# Epoch 40/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5953 - acc: 0.3787 - categorical_crossentropy: 1.5953
# Epoch 41/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5956 - acc: 0.3792 - categorical_crossentropy: 1.5956
# Epoch 42/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5955 - acc: 0.3780 - categorical_crossentropy: 1.5955
# Epoch 43/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5952 - acc: 0.3792 - categorical_crossentropy: 1.5952
# Epoch 44/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5956 - acc: 0.3803 - categorical_crossentropy: 1.5956
# Epoch 45/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.5955 - acc: 0.3801 - categorical_crossentropy: 1.5955
# Epoch 46/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5964 - acc: 0.3792 - categorical_crossentropy: 1.5964
# Epoch 47/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.5955 - acc: 0.3789 - categorical_crossentropy: 1.5955
# Epoch 48/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.5950 - acc: 0.3807 - categorical_crossentropy: 1.5950
# Epoch 49/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5950 - acc: 0.3794 - categorical_crossentropy: 1.5950
# Epoch 50/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5951 - acc: 0.3796 - categorical_crossentropy: 1.5951
# Epoch 51/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.5949 - acc: 0.3786 - categorical_crossentropy: 1.5949
# Epoch 52/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.5949 - acc: 0.3792 - categorical_crossentropy: 1.5949
# Epoch 53/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.5944 - acc: 0.3812 - categorical_crossentropy: 1.5944
# Epoch 54/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.5947 - acc: 0.3799 - categorical_crossentropy: 1.5947
# Epoch 55/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5957 - acc: 0.3787 - categorical_crossentropy: 1.5957
# Epoch 56/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5943 - acc: 0.3792 - categorical_crossentropy: 1.5943
# Epoch 57/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5941 - acc: 0.3805 - categorical_crossentropy: 1.5941
# Epoch 58/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5948 - acc: 0.3794 - categorical_crossentropy: 1.5948
# Epoch 59/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.5948 - acc: 0.3799 - categorical_crossentropy: 1.5948
# Epoch 60/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.5943 - acc: 0.3788 - categorical_crossentropy: 1.5943
# Epoch 61/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.5942 - acc: 0.3799 - categorical_crossentropy: 1.5942
# Epoch 62/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5939 - acc: 0.3796 - categorical_crossentropy: 1.5939
# Epoch 63/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.5935 - acc: 0.3804 - categorical_crossentropy: 1.5935
# Epoch 64/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5949 - acc: 0.3794 - categorical_crossentropy: 1.5949
# Epoch 65/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5946 - acc: 0.3789 - categorical_crossentropy: 1.5946
# Epoch 66/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5938 - acc: 0.3792 - categorical_crossentropy: 1.5938
# Epoch 67/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5940 - acc: 0.3794 - categorical_crossentropy: 1.5940
# Epoch 68/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5952 - acc: 0.3799 - categorical_crossentropy: 1.5952
# Epoch 69/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5938 - acc: 0.3803 - categorical_crossentropy: 1.5938
# Epoch 70/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5951 - acc: 0.3788 - categorical_crossentropy: 1.5951
# Epoch 71/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5938 - acc: 0.3798 - categorical_crossentropy: 1.5938
# Epoch 72/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.5938 - acc: 0.3805 - categorical_crossentropy: 1.5938
# Epoch 73/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5937 - acc: 0.3803 - categorical_crossentropy: 1.5937
# Epoch 74/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5933 - acc: 0.3797 - categorical_crossentropy: 1.5933
# Epoch 75/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5944 - acc: 0.3793 - categorical_crossentropy: 1.5944
# Epoch 76/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.5929 - acc: 0.3799 - categorical_crossentropy: 1.5929
# Epoch 77/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.5936 - acc: 0.3804 - categorical_crossentropy: 1.5936
# Epoch 78/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5938 - acc: 0.3786 - categorical_crossentropy: 1.5938
# Epoch 79/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5931 - acc: 0.3786 - categorical_crossentropy: 1.5931
# Epoch 80/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5936 - acc: 0.3781 - categorical_crossentropy: 1.5936
# Epoch 81/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5940 - acc: 0.3791 - categorical_crossentropy: 1.5940
# Epoch 82/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5945 - acc: 0.3786 - categorical_crossentropy: 1.5945
# Epoch 83/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5934 - acc: 0.3787 - categorical_crossentropy: 1.5934
# Epoch 84/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5947 - acc: 0.3796 - categorical_crossentropy: 1.5947
# Epoch 85/100
# 36020/36020 [==============================] - 1s 35us/step - loss: 1.5926 - acc: 0.3801 - categorical_crossentropy: 1.5926
# Epoch 86/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5930 - acc: 0.3801 - categorical_crossentropy: 1.5930
# Epoch 87/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5927 - acc: 0.3809 - categorical_crossentropy: 1.5927
# Epoch 88/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5929 - acc: 0.3793 - categorical_crossentropy: 1.5929
# Epoch 89/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5928 - acc: 0.3785 - categorical_crossentropy: 1.5928
# Epoch 90/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5938 - acc: 0.3803 - categorical_crossentropy: 1.5938
# Epoch 91/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5928 - acc: 0.3800 - categorical_crossentropy: 1.5928
# Epoch 92/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5948 - acc: 0.3801 - categorical_crossentropy: 1.5948
# Epoch 93/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5931 - acc: 0.3792 - categorical_crossentropy: 1.5931
# Epoch 94/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5925 - acc: 0.3810 - categorical_crossentropy: 1.5925
# Epoch 95/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5933 - acc: 0.3811 - categorical_crossentropy: 1.5933
# Epoch 96/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5936 - acc: 0.3800 - categorical_crossentropy: 1.5936
# Epoch 97/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5945 - acc: 0.3792 - categorical_crossentropy: 1.5945
# Epoch 98/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5930 - acc: 0.3813 - categorical_crossentropy: 1.5930
# Epoch 99/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5935 - acc: 0.3782 - categorical_crossentropy: 1.5935
# Epoch 100/100
# 36020/36020 [==============================] - 1s 36us/step - loss: 1.5944 - acc: 0.3774 - categorical_crossentropy: 1.5944
# Plotting training history data...
# dict_keys(['loss', 'categorical_crossentropy', 'acc'])
# Testing neural network...
# 0.8572283620539698
# /usr/local/lib/python3.5/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       268
#            1       0.00      0.03      0.01       233
#            2       0.07      0.02      0.03     11353
#            3       0.07      0.05      0.06     39525
#            4       0.05      0.80      0.09     19246
#            5       0.04      0.00      0.00    210481
#            6       1.00      0.96      0.98   2187456
#            7       0.04      0.04      0.04      8987
#            8       0.00      0.00      0.00       152
#            9       0.00      0.00      0.00        18
#
#     accuracy                           0.86   2477719
#    macro avg       0.13      0.19      0.12   2477719
# weighted avg       0.89      0.86      0.87   2477719
#
# Normalized confusion matrix
# [[0.00000000e+00 3.73134328e-03 1.49253731e-02 1.49253731e-02
#   9.32835821e-01 2.61194030e-02 0.00000000e+00 7.46268657e-03
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 3.43347639e-02 2.14592275e-02 2.57510730e-02
#   8.88412017e-01 1.71673820e-02 0.00000000e+00 1.28755365e-02
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 3.44402361e-02 2.02589624e-02 2.49273320e-02
#   8.89632696e-01 1.43574386e-02 0.00000000e+00 1.63833348e-02
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 2.11511701e-02 2.53763441e-02 5.30044276e-02
#   8.14522454e-01 4.09108159e-02 1.26502214e-04 4.49082859e-02
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 1.76660085e-02 2.19785930e-02 5.49205030e-02
#   8.03647511e-01 4.95687416e-02 4.15670789e-04 5.18029720e-02
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 4.84604311e-04 5.17861470e-04 1.43955987e-03
#   9.95263230e-01 1.11173930e-03 4.75102266e-06 1.17825362e-03
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 6.08012230e-05 6.08012230e-04 1.13634286e-02
#   2.24054792e-02 1.07247872e-03 9.62575247e-01 1.91455280e-03
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 9.23556248e-03 1.80260376e-02 3.59408034e-02
#   8.57015689e-01 4.12818516e-02 0.00000000e+00 3.85000556e-02
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 1.97368421e-02 2.63157895e-02
#   8.81578947e-01 3.28947368e-02 0.00000000e+00 3.94736842e-02
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 5.55555556e-02
#   7.77777778e-01 0.00000000e+00 0.00000000e+00 1.66666667e-01
#   0.00000000e+00 0.00000000e+00]]
# Saving neural network model...
# model3
# Fitting...
# Predicting...
# Testing accuracy...
# 0.8796102382877155
# /usr/local/lib/python3.5/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       268
#            1       0.01      0.03      0.01       233
#            2       0.03      0.25      0.06     11353
#            3       0.09      0.36      0.15     39525
#            4       0.09      0.32      0.14     19246
#            5       0.00      0.00      0.00    210481
#            6       1.00      0.99      0.99   2187456
#            7       0.14      0.10      0.12      8987
#            8       0.00      0.00      0.00       152
#            9       0.00      0.00      0.00        18
#
#     accuracy                           0.88   2477719
#    macro avg       0.14      0.21      0.15   2477719
# weighted avg       0.88      0.88      0.88   2477719
#
# Normalized confusion matrix
# [[0.00000000e+00 7.46268657e-03 2.98507463e-01 1.82835821e-01
#   5.03731343e-01 0.00000000e+00 3.73134328e-03 3.73134328e-03
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 3.43347639e-02 3.43347639e-01 1.33047210e-01
#   4.76394850e-01 4.29184549e-03 4.29184549e-03 4.29184549e-03
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 2.98599489e-02 2.53148947e-01 1.55729763e-01
#   5.37126751e-01 8.80824452e-05 9.68906897e-03 6.95851317e-03
#   7.39892539e-03 0.00000000e+00]
#  [0.00000000e+00 1.72043011e-02 1.58380772e-01 3.63820367e-01
#   3.83605313e-01 5.06008855e-05 3.10942441e-02 2.13029728e-02
#   2.45414295e-02 0.00000000e+00]
#  [0.00000000e+00 1.55356957e-02 7.97568326e-02 4.70175621e-01
#   3.15234334e-01 0.00000000e+00 2.54598358e-02 7.01964044e-02
#   2.36412761e-02 0.00000000e+00]
#  [0.00000000e+00 5.17861470e-04 3.48425749e-01 5.12212504e-01
#   1.36810448e-01 0.00000000e+00 1.39204964e-03 4.08587949e-04
#   2.32800110e-04 0.00000000e+00]
#  [0.00000000e+00 1.05144972e-05 9.62305070e-04 7.71855525e-03
#   4.26842871e-03 9.14304105e-07 9.85249989e-01 1.53100222e-03
#   2.58290910e-04 0.00000000e+00]
#  [0.00000000e+00 8.67920329e-03 9.07978191e-02 3.42828530e-01
#   4.52653833e-01 0.00000000e+00 4.11705797e-03 1.00923556e-01
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 1.97368421e-02 3.48684211e-01
#   5.92105263e-01 0.00000000e+00 0.00000000e+00 3.94736842e-02
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 5.55555556e-02 5.55555556e-01
#   2.77777778e-01 0.00000000e+00 0.00000000e+00 1.11111111e-01
#   0.00000000e+00 0.00000000e+00]]
# Saving X and Y to HDF5
