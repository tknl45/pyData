# %%
# confusion matrix
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_test, y_pred, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Greys):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure()
    cm = confusion_matrix(y_test, y_pred)
    # np.set_printoptions(precision=2)


    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, "{0:.4f}".format(cm[i, j]),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    
    
    
    #Roc


def plot_roc_curve(Y_test, Y_pred, nb_classes, class_index, title='Receiver operating characteristic'):
    from sklearn import metrics
    import matplotlib.pyplot as plt
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(nb_classes):
        fpr[i], tpr[i], _ = metrics.roc_curve(Y_test[:, i], Y_pred[:, i])
        roc_auc[i] = metrics.auc(fpr[i], tpr[i])
    
    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = metrics.roc_curve(Y_test.ravel(), Y_pred.ravel())
    roc_auc["micro"] = metrics.auc(fpr["micro"], tpr["micro"])
    
    #plt.figure()
    lw = 2
    plt.plot(fpr[class_index], tpr[class_index], color='darkorange',
             lw=lw, label='ROC curve (area = %0.4f)' % roc_auc[class_index])
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(title)
    plt.legend(loc="lower right")
    plt.show()
    
    #epoch history
    

def plot_hist(hist, metrics, num=None):
    import matplotlib.pyplot as plt
    if num is not None:
        fig = plt.figure(num)
    else:
        fig = plt.figure()
    ax1 = fig.add_subplot(111)
    for metric in metrics:
        ax1.plot(hist.history[metric], label=metric)
    # plt.plot(history.history['val_acc'])
    # ax.ylabel(metric)
    plt.title('model history')
    plt.xlabel('epoch')
    #plt.legend(['train', 'test'], loc='upper left')
    plt.legend(loc='upper right');
    plt.show()

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Input, merge, Lambda
from keras.models import Model
from keras.optimizers import SGD
import numpy as np

from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from keras.regularizers import l2 as activity_l2

from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

#from sklearn.metrics import confusion_matrix as cm
#from sklearn.metrics import roc_curve as roc
#from mlxtend.plotting import plot_confusion_matrix

#tagy
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
tf.Session(config=config)

print('Loading normalized data from HDF5...')
import h5py
h5f = h5py.File('datasets.h5', 'r')
X_train = h5f['X_nn_train'].value
Y_train = h5f['Y_nn_train'].value.astype(np.float32)
X_test = h5f['X_nn_test'].value
Y_test = h5f['Y_nn_test'].value.astype(np.float32)

X_train2 = h5f['X_rf_train'].value
Y_train2 = h5f['Y_rf_train'].value.astype(np.float32)
X_test2 = h5f['X_rf_test'].value
Y_test2 = h5f['Y_rf_test'].value.astype(np.float32)
h5f.close()


from sklearn.ensemble import ExtraTreesClassifier

print('Training ExtraTreesClassifier for "attack or not" labels...')
print('model2')
model2 = ExtraTreesClassifier(n_estimators=31, criterion='entropy')
model2 = model2.fit(X_train2, Y_train2)
Y_pred2 = model2.predict_proba(X_test2)[:,1]

print('Testing accuracy...')
score2 = accuracy_score(Y_test2, np.around(Y_pred2))
print(score2)
print(classification_report(Y_test2, np.around(Y_pred2)))

def perf_measure(y_actual, y_hat):
    TP = 0
    FP = 0
    TN = 0
    FN = 0

    for i in range(len(y_hat)): 
        if y_actual[i]==y_hat[i]==1:
           TP += 1
    for i in range(len(y_hat)): 
        if y_hat[i]==1 and y_actual[i]!=y_hat[i]:
           FP += 1
    for i in range(len(y_hat)): 
        if y_actual[i]==y_hat[i]==0:
           TN += 1
    for i in range(len(y_hat)): 
        if y_hat[i]==0 and y_actual[i]!=y_hat[i]:
           FN += 1

    return(TP, FP, TN, FN)

TP, FP, TN, FN = perf_measure(np.around(Y_pred2), Y_test2)

fp_rate = FP/(TN+FP)
tn_rate = TN/(TN+FP)

accuracy = (TN+TP)/(TN+FP+TP+TN)
precision = TP/(TN+FP)
hitrate = TP/(TN+FN)

print('TP:', TP, 'FP:', FP, 'TN:', TN, 'FN:', FN)
print('Accuracy:', accuracy)
print('False Positive rate:', fp_rate, 'True Negative Rate', tn_rate)

def to_cat(y):
    y_tmp = np.ndarray(shape=(y.shape[0], 2), dtype=np.float32)
    for i in range(y.shape[0]):
        y_tmp[i, :] = np.array([1-y[i], y[i]])   # np.array([0,1]) if y[i] else np.array([1,0])
    return y_tmp


plot_confusion_matrix(Y_test2, np.round(Y_pred2), classes=list(range(2)),
                           normalize=True,
                         title='"Intrusion or normal" confusion matrix')

plot_roc_curve(to_cat(Y_test2), to_cat(Y_pred2), 2, 0, title='Receiver operating characteristic (attack_or_not = 0)')
plot_roc_curve(to_cat(Y_test2), to_cat(Y_pred2), 2, 1, title='Receiver operating characteristic (attack_or_not = 1)')






if 'session' in locals() and session is not None:
    print('Close interactive session')
    session.close()
    
#  Starting Network shit


print('Combining predicted "attack or not" labels to neural network testing data...')
X_test = np.concatenate((Y_pred2[:,np.newaxis], X_test), axis=1)

print('Creating neural network...')
num_of_features = X_train.shape[1]
nb_classes = Y_train.shape[1]


def residual_layer(size, x):
    
    y = Dense(size, activation='sigmoid', W_regularizer=l2(0.01), activity_regularizer=activity_l2(0.01))(x)
    # x = Dropout(0.5)(x)
    # print(x.get_shape().as_list()[1])
    y = Dense(x.get_shape().as_list()[1], activation='sigmoid',  W_regularizer=l2(0.01), activity_regularizer=activity_l2(0.01))(y)
    res = merge([y, x], mode='sum')
    return res


def baseline_model():
    def branch2(x):
        
        x = Dense(int(np.floor(num_of_features*50)), activation='relu')(x)
        x = Dropout(0.75)(x)
        
        x = Dense(int(np.floor(num_of_features*20)), activation='relu')(x)
        x = Dropout(0.5)(x)
        
        x = Dense(int(np.floor(num_of_features)), activation='relu')(x)
        x = Dropout(0.1)(x)
        return x
    
    main_input = Input(shape=(num_of_features,), name='main_input')

    x = main_input
    x = branch2(x)
    main_output = Dense(nb_classes, activation='softmax')(x)
    model = Model(input=main_input, output=main_output)    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', 'categorical_crossentropy'])
    model.summary()
    return model
print('model...')
model = baseline_model()

print('Training neural network...')
history = model.fit(X_train, Y_train,
                    epochs=100,
                    batch_size=128
                    )

print('Plotting training history data...')
print(history.history.keys())

#from  epoch_history_plot import  plot_hist

plot_hist(history, ['loss', 'acc'])

# summarize history for accuracy
import matplotlib.pyplot as plt
plt.figure()
plt.plot(history.history['acc'])
#plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
#plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.figure()
# summarize history for loss
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
#plt.legend(['train', 'test'], loc='upper left')
plt.show()

print('Testing neural network...')
Y_predicted = model.predict(X_test)

max_probs = np.argmax(Y_predicted, axis=1)
Y_pred = np.zeros(Y_predicted.shape)
for row, col in enumerate(max_probs):
    Y_pred[row,col] = 1

score = accuracy_score(Y_test, Y_pred)
print(score)
print(classification_report(Y_test.argmax(axis=-1), Y_pred.argmax(axis=-1)))


plot_confusion_matrix(Y_test.argmax(axis=-1), Y_pred.argmax(axis=-1), classes=list(range(10)),
                          normalize=True,
                          title='Confusion matrix')

print('Saving neural network model...')
json_string = model.to_json()
with open('neural_model1.json', 'w') as f:
    f.write(json_string)
model.save_weights('neural_model_weights1.h5')

model.save('neural_model1.h5')

plot_roc_curve(Y_test, Y_predicted, nb_classes, 6, title='Receiver operating characteristic (class 6)')
plot_roc_curve(Y_test, Y_predicted, nb_classes, 4, title='Receiver operating characteristic (class 4)')
plot_roc_curve(Y_test, Y_predicted, nb_classes, 2, title='Receiver operating characteristic (class 2)')
plot_roc_curve(Y_test, Y_predicted, nb_classes, 0, title='Receiver operating characteristic (class 0)')

print('model3')
model3 = ExtraTreesClassifier(n_estimators=31, criterion='entropy')
print('Fitting...')
model3 = model3.fit(X_train, Y_train.argmax(axis=-1))
print('Predicting...')
Y_predicted3 = model3.predict(X_test)

print('Testing accuracy...')
score3 = accuracy_score(Y_test.argmax(axis=-1), Y_predicted3)
print(score3)
print(classification_report(Y_test.argmax(axis=-1), Y_predicted3))

plot_confusion_matrix(Y_test.argmax(axis=-1), Y_predicted3, classes=list(range(10)),
                          normalize=True,
                          title='Extratrees Confusion matrix')


print('Saving X and Y to HDF5')
h5f = h5py.File('results.h5', 'w')
h5f.create_dataset('Y_predicted', data=Y_pred)
h5f.create_dataset('Y_expected', data=Y_test)
h5f.close()
# Out:
# Using TensorFlow backend.
# Loading normalized data from HDF5...
# /usr/local/lib/python3.5/dist-packages/h5py/_hl/dataset.py:313: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   "Use dataset[()] instead.", H5pyDeprecationWarning)
# Training ExtraTreesClassifier for "attack or not" labels...
# model2
# Testing accuracy...
# 0.9839005149494353
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.98      0.99   2187456
#          1.0       0.88      1.00      0.94    290263
#
#     accuracy                           0.98   2477719
#    macro avg       0.94      0.99      0.96   2477719
# weighted avg       0.99      0.98      0.98   2477719
#
# TP: 289773 FP: 490 TN: 2148056 FN: 39400
# Accuracy: 0.53153721621106
# False Positive rate: 0.0002280612097669773 True Negative Rate 0.9997719387902331
# Normalized confusion matrix
# [[0.98198821 0.01801179]
#  [0.00168812 0.99831188]]
# Combining predicted "attack or not" labels to neural network testing data...
# Creating neural network...
# model...
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# main_input (InputLayer)      (None, 25)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1250)              32500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1250)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               625500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 25)                12525
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                260
# =================================================================
# Total params: 670,785
# Trainable params: 670,785
# Non-trainable params: 0
# _________________________________________________________________
# Training neural network...
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:150: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("ma..., outputs=Tensor("de...)`
# Epoch 1/100
# 36020/36020 [==============================] - 2s 69us/step - loss: 1.7009 - acc: 0.3505 - categorical_crossentropy: 1.7009
# Epoch 2/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.6338 - acc: 0.3663 - categorical_crossentropy: 1.6338
# Epoch 3/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.6252 - acc: 0.3701 - categorical_crossentropy: 1.6252
# Epoch 4/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6190 - acc: 0.3726 - categorical_crossentropy: 1.6190
# Epoch 5/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.6166 - acc: 0.3725 - categorical_crossentropy: 1.6166
# Epoch 6/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6139 - acc: 0.3736 - categorical_crossentropy: 1.6139
# Epoch 7/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.6117 - acc: 0.3752 - categorical_crossentropy: 1.6117
# Epoch 8/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6097 - acc: 0.3756 - categorical_crossentropy: 1.6097
# Epoch 9/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.6101 - acc: 0.3752 - categorical_crossentropy: 1.6101
# Epoch 10/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6073 - acc: 0.3765 - categorical_crossentropy: 1.6073
# Epoch 11/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6077 - acc: 0.3769 - categorical_crossentropy: 1.6077
# Epoch 12/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6072 - acc: 0.3765 - categorical_crossentropy: 1.6072
# Epoch 13/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6062 - acc: 0.3772 - categorical_crossentropy: 1.6062
# Epoch 14/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6062 - acc: 0.3770 - categorical_crossentropy: 1.6062
# Epoch 15/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6055 - acc: 0.3770 - categorical_crossentropy: 1.6055
# Epoch 16/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6045 - acc: 0.3782 - categorical_crossentropy: 1.6045
# Epoch 17/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6037 - acc: 0.3766 - categorical_crossentropy: 1.6037
# Epoch 18/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6050 - acc: 0.3762 - categorical_crossentropy: 1.6050
# Epoch 19/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6029 - acc: 0.3760 - categorical_crossentropy: 1.6029
# Epoch 20/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.6029 - acc: 0.3774 - categorical_crossentropy: 1.6029
# Epoch 21/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.6019 - acc: 0.3765 - categorical_crossentropy: 1.6019
# Epoch 22/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.6030 - acc: 0.3768 - categorical_crossentropy: 1.6030
# Epoch 23/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6026 - acc: 0.3768 - categorical_crossentropy: 1.6026
# Epoch 24/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6018 - acc: 0.3782 - categorical_crossentropy: 1.6018
# Epoch 25/100
# 36020/36020 [==============================] - 1s 17us/step - loss: 1.6016 - acc: 0.3780 - categorical_crossentropy: 1.6016
# Epoch 26/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.6017 - acc: 0.3770 - categorical_crossentropy: 1.6017
# Epoch 27/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6024 - acc: 0.3763 - categorical_crossentropy: 1.6024
# Epoch 28/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6010 - acc: 0.3776 - categorical_crossentropy: 1.6010
# Epoch 29/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.6022 - acc: 0.3766 - categorical_crossentropy: 1.6022
# Epoch 30/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6013 - acc: 0.3767 - categorical_crossentropy: 1.6013
# Epoch 31/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.6015 - acc: 0.3765 - categorical_crossentropy: 1.6015
# Epoch 32/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6010 - acc: 0.3783 - categorical_crossentropy: 1.6010
# Epoch 33/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.6004 - acc: 0.3774 - categorical_crossentropy: 1.6004
# Epoch 34/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.6014 - acc: 0.3780 - categorical_crossentropy: 1.6014
# Epoch 35/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.6007 - acc: 0.3784 - categorical_crossentropy: 1.6007
# Epoch 36/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.5992 - acc: 0.3767 - categorical_crossentropy: 1.5992
# Epoch 37/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.6002 - acc: 0.3782 - categorical_crossentropy: 1.6002
# Epoch 38/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.6001 - acc: 0.3796 - categorical_crossentropy: 1.6001
# Epoch 39/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5990 - acc: 0.3792 - categorical_crossentropy: 1.5990
# Epoch 40/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.6001 - acc: 0.3783 - categorical_crossentropy: 1.6001
# Epoch 41/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5988 - acc: 0.3780 - categorical_crossentropy: 1.5988
# Epoch 42/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5990 - acc: 0.3788 - categorical_crossentropy: 1.5990
# Epoch 43/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.5984 - acc: 0.3791 - categorical_crossentropy: 1.5984
# Epoch 44/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5986 - acc: 0.3786 - categorical_crossentropy: 1.5986
# Epoch 45/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.5979 - acc: 0.3783 - categorical_crossentropy: 1.5979
# Epoch 46/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.5988 - acc: 0.3795 - categorical_crossentropy: 1.5988
# Epoch 47/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5974 - acc: 0.3791 - categorical_crossentropy: 1.5974
# Epoch 48/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.5984 - acc: 0.3786 - categorical_crossentropy: 1.5984
# Epoch 49/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5972 - acc: 0.3799 - categorical_crossentropy: 1.5972
# Epoch 50/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.5972 - acc: 0.3789 - categorical_crossentropy: 1.5972
# Epoch 51/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.5974 - acc: 0.3799 - categorical_crossentropy: 1.5974
# Epoch 52/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5969 - acc: 0.3800 - categorical_crossentropy: 1.5969
# Epoch 53/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.5970 - acc: 0.3788 - categorical_crossentropy: 1.5970
# Epoch 54/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5965 - acc: 0.3801 - categorical_crossentropy: 1.5965
# Epoch 55/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5959 - acc: 0.3790 - categorical_crossentropy: 1.5959
# Epoch 56/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5961 - acc: 0.3791 - categorical_crossentropy: 1.5961
# Epoch 57/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5959 - acc: 0.3794 - categorical_crossentropy: 1.5959
# Epoch 58/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.5965 - acc: 0.3798 - categorical_crossentropy: 1.5965
# Epoch 59/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5966 - acc: 0.3803 - categorical_crossentropy: 1.5966
# Epoch 60/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.5957 - acc: 0.3786 - categorical_crossentropy: 1.5957
# Epoch 61/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5964 - acc: 0.3802 - categorical_crossentropy: 1.5964
# Epoch 62/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.5954 - acc: 0.3791 - categorical_crossentropy: 1.5954
# Epoch 63/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.5954 - acc: 0.3795 - categorical_crossentropy: 1.5954
# Epoch 64/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5945 - acc: 0.3807 - categorical_crossentropy: 1.5945
# Epoch 65/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5956 - acc: 0.3797 - categorical_crossentropy: 1.5956
# Epoch 66/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5954 - acc: 0.3807 - categorical_crossentropy: 1.5954
# Epoch 67/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5958 - acc: 0.3802 - categorical_crossentropy: 1.5958
# Epoch 68/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5959 - acc: 0.3803 - categorical_crossentropy: 1.5959
# Epoch 69/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5952 - acc: 0.3799 - categorical_crossentropy: 1.5952
# Epoch 70/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5955 - acc: 0.3791 - categorical_crossentropy: 1.5955
# Epoch 71/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5956 - acc: 0.3798 - categorical_crossentropy: 1.5956
# Epoch 72/100
# 36020/36020 [==============================] - 1s 17us/step - loss: 1.5958 - acc: 0.3804 - categorical_crossentropy: 1.5958
# Epoch 73/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5953 - acc: 0.3801 - categorical_crossentropy: 1.5953
# Epoch 74/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.5948 - acc: 0.3798 - categorical_crossentropy: 1.5948
# Epoch 75/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5945 - acc: 0.3799 - categorical_crossentropy: 1.5945
# Epoch 76/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.5948 - acc: 0.3793 - categorical_crossentropy: 1.5948
# Epoch 77/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5945 - acc: 0.3805 - categorical_crossentropy: 1.5945
# Epoch 78/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5954 - acc: 0.3797 - categorical_crossentropy: 1.5954
# Epoch 79/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5951 - acc: 0.3796 - categorical_crossentropy: 1.5951
# Epoch 80/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.5950 - acc: 0.3794 - categorical_crossentropy: 1.5950
# Epoch 81/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5953 - acc: 0.3813 - categorical_crossentropy: 1.5953
# Epoch 82/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5946 - acc: 0.3807 - categorical_crossentropy: 1.5946
# Epoch 83/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5945 - acc: 0.3803 - categorical_crossentropy: 1.5945
# Epoch 84/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5953 - acc: 0.3809 - categorical_crossentropy: 1.5953
# Epoch 85/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5952 - acc: 0.3792 - categorical_crossentropy: 1.5952
# Epoch 86/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5951 - acc: 0.3793 - categorical_crossentropy: 1.5951
# Epoch 87/100
# 36020/36020 [==============================] - 1s 19us/step - loss: 1.5942 - acc: 0.3810 - categorical_crossentropy: 1.5942
# Epoch 88/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5945 - acc: 0.3798 - categorical_crossentropy: 1.5945
# Epoch 89/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5944 - acc: 0.3806 - categorical_crossentropy: 1.5944
# Epoch 90/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5949 - acc: 0.3793 - categorical_crossentropy: 1.5949
# Epoch 91/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5940 - acc: 0.3810 - categorical_crossentropy: 1.5940
# Epoch 92/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5943 - acc: 0.3802 - categorical_crossentropy: 1.5943
# Epoch 93/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5947 - acc: 0.3803 - categorical_crossentropy: 1.5947
# Epoch 94/100
# 36020/36020 [==============================] - 1s 17us/step - loss: 1.5942 - acc: 0.3807 - categorical_crossentropy: 1.5942
# Epoch 95/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5948 - acc: 0.3790 - categorical_crossentropy: 1.5948
# Epoch 96/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5947 - acc: 0.3811 - categorical_crossentropy: 1.5947
# Epoch 97/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5951 - acc: 0.3792 - categorical_crossentropy: 1.5951
# Epoch 98/100
# 36020/36020 [==============================] - 1s 17us/step - loss: 1.5947 - acc: 0.3814 - categorical_crossentropy: 1.5947
# Epoch 99/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5938 - acc: 0.3793 - categorical_crossentropy: 1.5938
# Epoch 100/100
# 36020/36020 [==============================] - 1s 18us/step - loss: 1.5939 - acc: 0.3791 - categorical_crossentropy: 1.5939
# Plotting training history data...
# dict_keys(['acc', 'categorical_crossentropy', 'loss'])
# Testing neural network...
# 0.9494809540549191
# /usr/local/lib/python3.5/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       268
#            1       0.00      0.04      0.01       233
#            2       0.05      0.05      0.05     11353
#            3       0.02      0.00      0.00     39525
#            4       0.15      0.53      0.23     19246
#            5       0.82      0.98      0.90    210481
#            6       1.00      0.98      0.99   2187456
#            7       0.05      0.03      0.04      8987
#            8       0.00      0.00      0.00       152
#            9       0.00      0.00      0.00        18
#
#     accuracy                           0.95   2477719
#    macro avg       0.21      0.26      0.22   2477719
# weighted avg       0.95      0.95      0.95   2477719
#
# Normalized confusion matrix
# [[0.00000000e+00 3.73134328e-03 4.10447761e-02 0.00000000e+00
#   1.82835821e-01 7.64925373e-01 0.00000000e+00 7.46268657e-03
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 3.86266094e-02 5.15021459e-02 4.29184549e-03
#   1.15879828e-01 7.81115880e-01 0.00000000e+00 8.58369099e-03
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 3.84039461e-02 4.66836959e-02 8.80824452e-04
#   1.72817757e-01 7.29234564e-01 2.64247336e-04 1.17149652e-02
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 2.33270082e-02 5.17394054e-02 2.25173941e-03
#   5.28273245e-01 3.61568627e-01 8.34914611e-04 3.20050601e-02
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 2.05237452e-02 5.17510132e-02 1.92247740e-03
#   5.31435103e-01 3.49215421e-01 3.06557207e-03 4.20866674e-02
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 5.41616583e-04 1.28752714e-03 9.97714758e-05
#   1.24476794e-02 9.84544923e-01 1.18775566e-04 9.59706577e-04
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 2.74291231e-05 3.04143260e-03 2.33513268e-03
#   1.31550075e-02 4.67712265e-03 9.75653453e-01 1.11042234e-03
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 1.01257372e-02 3.86113275e-02 1.11271837e-04
#   4.13597418e-01 5.07844665e-01 3.33815511e-04 2.93757650e-02
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 1.97368421e-02 0.00000000e+00
#   4.53947368e-01 5.26315789e-01 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   6.66666667e-01 2.77777778e-01 0.00000000e+00 5.55555556e-02
#   0.00000000e+00 0.00000000e+00]]
# Saving neural network model...
# model3
# Fitting...
# Predicting...
# Testing accuracy...
# 0.8786726824147533
# /usr/local/lib/python3.5/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       268
#            1       0.00      0.01      0.00       233
#            2       0.05      0.69      0.09     11353
#            3       0.05      0.11      0.06     39525
#            4       0.18      0.48      0.26     19246
#            5       0.18      0.00      0.00    210481
#            6       1.00      0.99      0.99   2187456
#            7       0.06      0.00      0.00      8987
#            8       0.00      0.00      0.00       152
#            9       0.00      0.00      0.00        18
#
#     accuracy                           0.88   2477719
#    macro avg       0.15      0.23      0.14   2477719
# weighted avg       0.90      0.88      0.88   2477719
#
# Normalized confusion matrix
# [[0.00000000e+00 0.00000000e+00 6.11940299e-01 1.97761194e-01
#   1.90298507e-01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 1.28755365e-02 6.90987124e-01 1.84549356e-01
#   1.11587983e-01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 5.90152383e-03 6.86602660e-01 1.33444904e-01
#   1.31242843e-01 5.28494671e-04 1.58548401e-02 3.52329781e-04
#   2.60724038e-02 0.00000000e+00]
#  [0.00000000e+00 1.87476281e-02 3.33434535e-01 1.12106262e-01
#   4.00227704e-01 2.53004428e-04 4.91334598e-02 1.44212524e-03
#   8.46299810e-02 2.53004428e-05]
#  [0.00000000e+00 4.31258443e-02 2.27319963e-01 1.36443936e-01
#   4.77709654e-01 1.29897121e-03 3.76701652e-02 2.54598358e-03
#   7.38854827e-02 0.00000000e+00]
#  [0.00000000e+00 2.28049088e-04 5.89958239e-01 3.96045249e-01
#   1.04760050e-02 7.60163625e-05 1.90516009e-03 1.90040906e-05
#   1.29227816e-03 0.00000000e+00]
#  [0.00000000e+00 9.57733550e-04 2.22633050e-03 1.65809049e-03
#   8.68726045e-03 1.37145616e-05 9.85458908e-01 7.26871763e-05
#   9.25275754e-04 0.00000000e+00]
#  [0.00000000e+00 5.74162679e-02 1.90163570e-01 2.76621787e-01
#   4.65338823e-01 1.11271837e-04 8.45665962e-03 1.89162123e-03
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 3.94736842e-02 4.34210526e-01 3.28947368e-02
#   4.73684211e-01 0.00000000e+00 6.57894737e-03 1.31578947e-02
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 5.55555556e-02 2.22222222e-01 1.11111111e-01
#   5.00000000e-01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   1.11111111e-01 0.00000000e+00]]
# Saving X and Y to HDF5
